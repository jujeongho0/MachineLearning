# %%
import numpy as np
from google.colab import drive
from tensorflow.keras.utils import to_categorical

drive.mount('/content/drive')
train_data_path = "/content/drive/My Drive/기계학습 실습/train_data.npy" # Your train data file
train_label_path = "/content/drive/My Drive/기계학습 실습/train_label.npy" # Your train label file
test_data_path = "/content/drive/My Drive/기계학습 실습/test_data.npy" # Your train data file
test_label_path = "/content/drive/My Drive/기계학습 실습/test_label2.npy" # Your train label file

x_train = np.load(train_data_path, allow_pickle=True) # (2682,) max = 502
y_train = np.load(train_label_path, allow_pickle=True)  #(2682,)
x_test = np.load(test_data_path, allow_pickle=True) # (2690,) max = 432
y_test = np.load(test_label_path, allow_pickle=True) # (2690,)

# 라벨 정수 인코딩
label = []
train_label = []
test_label = []
rating = ['18k', '17k', '16k', '15k', '14k', '13k', '12k', '11k', '10k', 
          '9k', '8k', '7k', '6k', '5k', '4k', '3k', '2k', '1k',
          '1d', '2d', '3d', '4d', '5d', '6d', '7d', '8d', '9d']
for i in range(2682):
    label.append(rating.index(y_train[i])) 

for i in range(2690):
    label.append(rating.index(y_test[i]))

label = np.array(label) 
label= to_categorical(label)

length = 50
train_encoded = np.zeros((5372,length,19,19))

for i in range(2682):
    for j in range(length):
        try:
            for row in range(0,19):
                for col in range(0,19):
                    if x_train[i][j][0][row][col] == -1 :
                        train_encoded[i][j][row][col] = 200
                    elif x_train[i][j][0][row][col] == 1 :
                        train_encoded[i][j][row][col] = 100
                    else:
                        train_encoded[i][j][row][col] = x_train[i][j][0][row][col]
        except:
            continue

for i in range(2690):
    for j in range(length):
        try:
            for row in range(0,19):
                for col in range(0,19):
                    if x_test[i][j][0][row][col] == -1 :
                        train_encoded[i+2682][j][row][col] = 200
                    elif x_test[i][j][0][row][col] == 1 :
                        train_encoded[i+2682][j][row][col] = 100
                    else:
                        train_encoded[i+2682][j][row][col] = x_test[i][j][0][row][col]
        except:
            continue

query_path = "/content/drive/My Drive/기계학습 실습/Test2_data.npy" 
query = np.load(query_path, allow_pickle=True) 

query_list = np.zeros((2690,length,19,19))

for i in range(2690):
    for j in range(length):
        try:
            for row in range(0,19):
                for col in range(0,19):
                    if query[i][j][0][row][col] == -1 :
                        query_list[i][j][row][col] = 200
                    elif query[i][j][0][row][col] == 1 :
                        query_list[i][j][row][col] = 100
                    else:
                        query_list[i][j][row][col] = query[i][j][0][row][col]
        except:
            continue
            
query_list = query_list.reshape((2690,length,19,19,1))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
from google.colab import drive
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, AveragePooling2D, ConvLSTM2D, Flatten, TimeDistributed
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %tensorflow_version 2.x
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')

train_encoded = train_encoded.reshape(5372,length,19,19,1)
x_train, x_test, y_train, y_test = train_test_split(train_encoded, label, test_size=.1, random_state=777)

with tf.device('/device:GPU:0'):
    
    predict_list = []
    for i in range(10):
        model = Sequential()
        
        model.add(ConvLSTM2D(filters = 64, kernel_size = (4,4), return_sequences = True, input_shape = (length, 19, 19, 1)))  
        model.add(Activation('relu'))    
        model.add(TimeDistributed(AveragePooling2D(2,2)))
        
        model.add(ConvLSTM2D(filters = 64, kernel_size = (4, 4), return_sequences = True))   
        model.add(Activation('relu'))
        model.add(TimeDistributed(AveragePooling2D(5,5)))   

        model.add(Flatten())
        
        model.add(Dense(960))
        model.add(Activation('relu'))

        model.add(Dense(480))
        model.add(Activation('relu'))

        model.add(Dense(240))
        model.add(Activation('relu'))
        
        model.add(Dense(27, activation = "softmax"))
        
        model.summary()
        
        es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=12)
        mc = ModelCheckpoint('ML_team1.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)
        model.compile(loss='categorical_crossentropy', optimizer= 'RMSProp' , metrics=['acc'])

        history = model.fit(x_train, y_train, batch_size=16, callbacks=[es, mc], epochs=90, validation_data=(x_test, y_test))

        predict_list.append(model.predict(query_list))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_lst_m2d (ConvLSTM2D)    (None, 50, 16, 16, 64)    266496
# _________________________________________________________________
# activation (Activation)      (None, 50, 16, 16, 64)    0
# _________________________________________________________________
# time_distributed (TimeDistri (None, 50, 8, 8, 64)      0
# _________________________________________________________________
# conv_lst_m2d_1 (ConvLSTM2D)  (None, 50, 5, 5, 64)      524544
# _________________________________________________________________
# activation_1 (Activation)    (None, 50, 5, 5, 64)      0
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 50, 1, 1, 64)      0
# _________________________________________________________________
# flatten (Flatten)            (None, 3200)              0
# _________________________________________________________________
# dense (Dense)                (None, 960)               3072960
# _________________________________________________________________
# activation_2 (Activation)    (None, 960)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 480)               461280
# _________________________________________________________________
# activation_3 (Activation)    (None, 480)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 240)               115440
# _________________________________________________________________
# activation_4 (Activation)    (None, 240)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 27)                6507
# =================================================================
# Total params: 4,447,227
# Trainable params: 4,447,227
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/90
# 303/303 [==============================] - 167s 483ms/step - loss: 3.3422 - acc: 0.0330 - val_loss: 3.2952 - val_acc: 0.0223
#
# Epoch 00001: val_acc improved from -inf to 0.02230, saving model to ML_team1.h5
# Epoch 2/90
# 303/303 [==============================] - 148s 487ms/step - loss: 3.2914 - acc: 0.0438 - val_loss: 3.2075 - val_acc: 0.0874
#
# Epoch 00002: val_acc improved from 0.02230 to 0.08736, saving model to ML_team1.h5
# Epoch 3/90
# 303/303 [==============================] - 149s 492ms/step - loss: 3.2242 - acc: 0.0809 - val_loss: 3.1757 - val_acc: 0.0967
#
# Epoch 00003: val_acc improved from 0.08736 to 0.09665, saving model to ML_team1.h5
# Epoch 4/90
# 303/303 [==============================] - 154s 507ms/step - loss: 3.1898 - acc: 0.0843 - val_loss: 3.2205 - val_acc: 0.1022
#
# Epoch 00004: val_acc improved from 0.09665 to 0.10223, saving model to ML_team1.h5
# Epoch 5/90
# 303/303 [==============================] - 148s 487ms/step - loss: 3.1617 - acc: 0.0939 - val_loss: 3.2288 - val_acc: 0.0874
#
# Epoch 00005: val_acc did not improve from 0.10223
# Epoch 6/90
# 303/303 [==============================] - 149s 491ms/step - loss: 3.1349 - acc: 0.0941 - val_loss: 3.2010 - val_acc: 0.0911
#
# Epoch 00006: val_acc did not improve from 0.10223
# Epoch 7/90
# 303/303 [==============================] - 147s 485ms/step - loss: 3.1463 - acc: 0.0908 - val_loss: 3.1566 - val_acc: 0.1022
#
# Epoch 00007: val_acc did not improve from 0.10223
# Epoch 8/90
# 303/303 [==============================] - 148s 489ms/step - loss: 3.1244 - acc: 0.0853 - val_loss: 3.1519 - val_acc: 0.0855
#
# Epoch 00008: val_acc did not improve from 0.10223
# Epoch 9/90
# 303/303 [==============================] - 150s 496ms/step - loss: 3.0818 - acc: 0.0994 - val_loss: 3.1540 - val_acc: 0.1190
#
# Epoch 00009: val_acc improved from 0.10223 to 0.11896, saving model to ML_team1.h5
# Epoch 10/90
# 303/303 [==============================] - 150s 496ms/step - loss: 3.0769 - acc: 0.1061 - val_loss: 3.0834 - val_acc: 0.1227
#
# Epoch 00010: val_acc improved from 0.11896 to 0.12268, saving model to ML_team1.h5
# Epoch 11/90
# 303/303 [==============================] - 150s 494ms/step - loss: 3.0019 - acc: 0.1226 - val_loss: 3.0909 - val_acc: 0.1097
#
# Epoch 00011: val_acc did not improve from 0.12268
# Epoch 12/90
# 303/303 [==============================] - 151s 499ms/step - loss: 3.0015 - acc: 0.1177 - val_loss: 3.1474 - val_acc: 0.1022
#
# Epoch 00012: val_acc did not improve from 0.12268
# Epoch 13/90
# 303/303 [==============================] - 151s 499ms/step - loss: 2.9506 - acc: 0.1270 - val_loss: 3.2105 - val_acc: 0.0743
#
# Epoch 00013: val_acc did not improve from 0.12268
# Epoch 14/90
# 303/303 [==============================] - 149s 492ms/step - loss: 2.9126 - acc: 0.1302 - val_loss: 3.1776 - val_acc: 0.1041
#
# Epoch 00014: val_acc did not improve from 0.12268
# Epoch 15/90
# 303/303 [==============================] - 152s 502ms/step - loss: 2.8742 - acc: 0.1365 - val_loss: 3.1101 - val_acc: 0.0836
#
# Epoch 00015: val_acc did not improve from 0.12268
# Epoch 16/90
# 303/303 [==============================] - 153s 506ms/step - loss: 2.8079 - acc: 0.1484 - val_loss: 3.1953 - val_acc: 0.0911
#
# Epoch 00016: val_acc did not improve from 0.12268
# Epoch 17/90
# 303/303 [==============================] - 151s 499ms/step - loss: 2.7561 - acc: 0.1773 - val_loss: 3.2036 - val_acc: 0.1022
#
# Epoch 00017: val_acc did not improve from 0.12268
# Epoch 18/90
# 303/303 [==============================] - 151s 499ms/step - loss: 2.7089 - acc: 0.1735 - val_loss: 3.1934 - val_acc: 0.1097
#
# Epoch 00018: val_acc did not improve from 0.12268
# Epoch 19/90
# 303/303 [==============================] - 151s 500ms/step - loss: 2.6479 - acc: 0.1825 - val_loss: 3.4243 - val_acc: 0.0818
#
# Epoch 00019: val_acc did not improve from 0.12268
# Epoch 20/90
# 303/303 [==============================] - 152s 501ms/step - loss: 2.5742 - acc: 0.2046 - val_loss: 3.4432 - val_acc: 0.1134
#
# Epoch 00020: val_acc did not improve from 0.12268
# Epoch 21/90
# 303/303 [==============================] - 152s 503ms/step - loss: 2.4945 - acc: 0.2119 - val_loss: 3.3686 - val_acc: 0.1171
#
# Epoch 00021: val_acc did not improve from 0.12268
# Epoch 22/90
# 303/303 [==============================] - 151s 497ms/step - loss: 2.4641 - acc: 0.2283 - val_loss: 3.5755 - val_acc: 0.0874
#
# Epoch 00022: val_acc did not improve from 0.12268
# Epoch 00022: early stopping
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_lst_m2d_2 (ConvLSTM2D)  (None, 50, 16, 16, 64)    266496
# _________________________________________________________________
# activation_5 (Activation)    (None, 50, 16, 16, 64)    0
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 50, 8, 8, 64)      0
# _________________________________________________________________
# conv_lst_m2d_3 (ConvLSTM2D)  (None, 50, 5, 5, 64)      524544
# _________________________________________________________________
# activation_6 (Activation)    (None, 50, 5, 5, 64)      0
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, 50, 1, 1, 64)      0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3200)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 960)               3072960
# _________________________________________________________________
# activation_7 (Activation)    (None, 960)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 480)               461280
# _________________________________________________________________
# activation_8 (Activation)    (None, 480)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 240)               115440
# _________________________________________________________________
# activation_9 (Activation)    (None, 240)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 27)                6507
# =================================================================
# Total params: 4,447,227
# Trainable params: 4,447,227
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/90
# 303/303 [==============================] - 153s 491ms/step - loss: 3.3331 - acc: 0.0312 - val_loss: 3.2970 - val_acc: 0.0316
#
# Epoch 00001: val_acc improved from -inf to 0.03160, saving model to ML_team1.h5
# Epoch 2/90
# 303/303 [==============================] - 148s 489ms/step - loss: 3.2964 - acc: 0.0301 - val_loss: 3.2494 - val_acc: 0.1059
#
# Epoch 00002: val_acc improved from 0.03160 to 0.10595, saving model to ML_team1.h5
# Epoch 3/90
# 303/303 [==============================] - 146s 481ms/step - loss: 3.2476 - acc: 0.0773 - val_loss: 3.4660 - val_acc: 0.0929
#
# Epoch 00003: val_acc did not improve from 0.10595
# Epoch 4/90
# 303/303 [==============================] - 147s 484ms/step - loss: 3.1904 - acc: 0.0849 - val_loss: 3.1923 - val_acc: 0.0781
#
# Epoch 00004: val_acc did not improve from 0.10595
# Epoch 5/90
# 303/303 [==============================] - 149s 491ms/step - loss: 3.1497 - acc: 0.0901 - val_loss: 3.2433 - val_acc: 0.0706
#
# Epoch 00005: val_acc did not improve from 0.10595
# Epoch 6/90
# 303/303 [==============================] - 147s 485ms/step - loss: 3.1153 - acc: 0.0915 - val_loss: 3.1815 - val_acc: 0.0911
#
# Epoch 00006: val_acc did not improve from 0.10595
# Epoch 7/90
# 303/303 [==============================] - 147s 484ms/step - loss: 3.0767 - acc: 0.1008 - val_loss: 3.1612 - val_acc: 0.0929
#
# Epoch 00007: val_acc did not improve from 0.10595
# Epoch 8/90
# 303/303 [==============================] - 146s 483ms/step - loss: 3.0385 - acc: 0.1154 - val_loss: 3.1592 - val_acc: 0.1059
#
# Epoch 00008: val_acc did not improve from 0.10595
# Epoch 9/90
# 303/303 [==============================] - 146s 482ms/step - loss: 2.9806 - acc: 0.1215 - val_loss: 3.1307 - val_acc: 0.1059
#
# Epoch 00009: val_acc did not improve from 0.10595
# Epoch 10/90
# 303/303 [==============================] - 145s 480ms/step - loss: 2.9530 - acc: 0.1265 - val_loss: 3.3907 - val_acc: 0.0836
#
# Epoch 00010: val_acc did not improve from 0.10595
# Epoch 11/90
# 303/303 [==============================] - 146s 483ms/step - loss: 2.9366 - acc: 0.1260 - val_loss: 3.1651 - val_acc: 0.0929
#
# Epoch 00011: val_acc did not improve from 0.10595
# Epoch 12/90
# 303/303 [==============================] - 147s 484ms/step - loss: 2.9063 - acc: 0.1393 - val_loss: 3.1270 - val_acc: 0.1264
#
# Epoch 00012: val_acc improved from 0.10595 to 0.12639, saving model to ML_team1.h5
# Epoch 13/90
# 303/303 [==============================] - 147s 486ms/step - loss: 2.8284 - acc: 0.1580 - val_loss: 3.3906 - val_acc: 0.1320
#
# Epoch 00013: val_acc improved from 0.12639 to 0.13197, saving model to ML_team1.h5
# Epoch 14/90
# 303/303 [==============================] - 147s 484ms/step - loss: 2.8142 - acc: 0.1527 - val_loss: 3.3283 - val_acc: 0.0818
#
# Epoch 00014: val_acc did not improve from 0.13197
# Epoch 15/90
# 303/303 [==============================] - 147s 486ms/step - loss: 2.7228 - acc: 0.1667 - val_loss: 3.2011 - val_acc: 0.1059
#
# Epoch 00015: val_acc did not improve from 0.13197
# Epoch 16/90
# 303/303 [==============================] - 147s 486ms/step - loss: 2.6739 - acc: 0.1884 - val_loss: 3.2539 - val_acc: 0.1078
#
# Epoch 00016: val_acc did not improve from 0.13197
# Epoch 17/90
# 303/303 [==============================] - 147s 485ms/step - loss: 2.6232 - acc: 0.1970 - val_loss: 3.2815 - val_acc: 0.0762
#
# Epoch 00017: val_acc did not improve from 0.13197
# Epoch 18/90
# 303/303 [==============================] - 148s 487ms/step - loss: 2.5651 - acc: 0.2092 - val_loss: 3.8758 - val_acc: 0.1115
#
# Epoch 00018: val_acc did not improve from 0.13197
# Epoch 19/90
# 303/303 [==============================] - 147s 485ms/step - loss: 2.5363 - acc: 0.2311 - val_loss: 3.5349 - val_acc: 0.1134
#
# Epoch 00019: val_acc did not improve from 0.13197
# Epoch 20/90
# 303/303 [==============================] - 145s 479ms/step - loss: 2.4142 - acc: 0.2540 - val_loss: 3.4929 - val_acc: 0.0948
#
# Epoch 00020: val_acc did not improve from 0.13197
# Epoch 21/90
# 303/303 [==============================] - 146s 482ms/step - loss: 2.3007 - acc: 0.2793 - val_loss: 3.6424 - val_acc: 0.0911
#
# Epoch 00021: val_acc did not improve from 0.13197
# Epoch 22/90
# 303/303 [==============================] - 149s 491ms/step - loss: 2.2321 - acc: 0.2938 - val_loss: 4.1513 - val_acc: 0.1227
#
# Epoch 00022: val_acc did not improve from 0.13197
# Epoch 23/90
# 303/303 [==============================] - 148s 490ms/step - loss: 2.1746 - acc: 0.3095 - val_loss: 4.3691 - val_acc: 0.1413
#
# Epoch 00023: val_acc improved from 0.13197 to 0.14126, saving model to ML_team1.h5
# Epoch 24/90
# 303/303 [==============================] - 146s 483ms/step - loss: 2.0854 - acc: 0.3512 - val_loss: 4.5704 - val_acc: 0.0688
#
# Epoch 00024: val_acc did not improve from 0.14126
# Epoch 00024: early stopping
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_lst_m2d_4 (ConvLSTM2D)  (None, 50, 16, 16, 64)    266496
# _________________________________________________________________
# activation_10 (Activation)   (None, 50, 16, 16, 64)    0
# _________________________________________________________________
# time_distributed_4 (TimeDist (None, 50, 8, 8, 64)      0
# _________________________________________________________________
# conv_lst_m2d_5 (ConvLSTM2D)  (None, 50, 5, 5, 64)      524544
# _________________________________________________________________
# activation_11 (Activation)   (None, 50, 5, 5, 64)      0
# _________________________________________________________________
# time_distributed_5 (TimeDist (None, 50, 1, 1, 64)      0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 3200)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 960)               3072960
# _________________________________________________________________
# activation_12 (Activation)   (None, 960)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 480)               461280
# _________________________________________________________________
# activation_13 (Activation)   (None, 480)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 240)               115440
# _________________________________________________________________
# activation_14 (Activation)   (None, 240)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 27)                6507
# =================================================================
# Total params: 4,447,227
# Trainable params: 4,447,227
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/90
# 303/303 [==============================] - 155s 495ms/step - loss: 3.3391 - acc: 0.0335 - val_loss: 3.2961 - val_acc: 0.0297
#
# Epoch 00001: val_acc improved from -inf to 0.02974, saving model to ML_team1.h5
# Epoch 2/90
# 303/303 [==============================] - 149s 492ms/step - loss: 3.2814 - acc: 0.0512 - val_loss: 3.2540 - val_acc: 0.0874
#
# Epoch 00002: val_acc improved from 0.02974 to 0.08736, saving model to ML_team1.h5
# Epoch 3/90
# 303/303 [==============================] - 151s 500ms/step - loss: 3.2100 - acc: 0.0841 - val_loss: 3.1234 - val_acc: 0.0967
#
# Epoch 00003: val_acc improved from 0.08736 to 0.09665, saving model to ML_team1.h5
# Epoch 4/90
# 303/303 [==============================] - 153s 506ms/step - loss: 3.1459 - acc: 0.0929 - val_loss: 3.1624 - val_acc: 0.0985
#
# Epoch 00004: val_acc improved from 0.09665 to 0.09851, saving model to ML_team1.h5
# Epoch 5/90
# 303/303 [==============================] - 154s 509ms/step - loss: 3.1202 - acc: 0.1012 - val_loss: 3.1656 - val_acc: 0.1041
#
# Epoch 00005: val_acc improved from 0.09851 to 0.10409, saving model to ML_team1.h5
# Epoch 6/90
# 303/303 [==============================] - 156s 515ms/step - loss: 3.0805 - acc: 0.1024 - val_loss: 3.1076 - val_acc: 0.1041
#
# Epoch 00006: val_acc did not improve from 0.10409
# Epoch 7/90
# 303/303 [==============================] - 156s 514ms/step - loss: 3.0383 - acc: 0.1124 - val_loss: 3.1294 - val_acc: 0.0948
#
# Epoch 00007: val_acc did not improve from 0.10409
# Epoch 8/90
# 303/303 [==============================] - 156s 513ms/step - loss: 3.0056 - acc: 0.1175 - val_loss: 3.1320 - val_acc: 0.0911
#
# Epoch 00008: val_acc did not improve from 0.10409
# Epoch 9/90
# 303/303 [==============================] - 155s 510ms/step - loss: 2.9667 - acc: 0.1187 - val_loss: 3.1842 - val_acc: 0.0818
#
# Epoch 00009: val_acc did not improve from 0.10409
# Epoch 10/90
# 303/303 [==============================] - 154s 508ms/step - loss: 2.9520 - acc: 0.1122 - val_loss: 3.0481 - val_acc: 0.1004
#
# Epoch 00010: val_acc did not improve from 0.10409
# Epoch 11/90
# 303/303 [==============================] - 154s 509ms/step - loss: 2.8921 - acc: 0.1342 - val_loss: 3.2443 - val_acc: 0.1059
#
# Epoch 00011: val_acc improved from 0.10409 to 0.10595, saving model to ML_team1.h5
# Epoch 12/90
# 303/303 [==============================] - 152s 502ms/step - loss: 2.8854 - acc: 0.1311 - val_loss: 3.1358 - val_acc: 0.1208
#
# Epoch 00012: val_acc improved from 0.10595 to 0.12082, saving model to ML_team1.h5
# Epoch 13/90
# 303/303 [==============================] - 149s 492ms/step - loss: 2.8322 - acc: 0.1442 - val_loss: 3.5234 - val_acc: 0.1059
#
# Epoch 00013: val_acc did not improve from 0.12082
# Epoch 14/90
# 303/303 [==============================] - 148s 488ms/step - loss: 2.8154 - acc: 0.1465 - val_loss: 3.1891 - val_acc: 0.1134
#
# Epoch 00014: val_acc did not improve from 0.12082
# Epoch 15/90
# 303/303 [==============================] - 148s 489ms/step - loss: 2.7547 - acc: 0.1547 - val_loss: 3.3530 - val_acc: 0.1078
#
# Epoch 00015: val_acc did not improve from 0.12082
# Epoch 16/90
# 303/303 [==============================] - 148s 488ms/step - loss: 2.6748 - acc: 0.1718 - val_loss: 3.1977 - val_acc: 0.1208
#
# Epoch 00016: val_acc did not improve from 0.12082
# Epoch 17/90
# 303/303 [==============================] - 149s 492ms/step - loss: 2.6456 - acc: 0.1734 - val_loss: 3.4148 - val_acc: 0.1264
#
# Epoch 00017: val_acc improved from 0.12082 to 0.12639, saving model to ML_team1.h5
# Epoch 18/90
# 303/303 [==============================] - 148s 489ms/step - loss: 2.5947 - acc: 0.1890 - val_loss: 3.5391 - val_acc: 0.1264
#
# Epoch 00018: val_acc did not improve from 0.12639
# Epoch 19/90
# 303/303 [==============================] - 149s 492ms/step - loss: 2.5714 - acc: 0.1965 - val_loss: 3.4470 - val_acc: 0.1059
#
# Epoch 00019: val_acc did not improve from 0.12639
# Epoch 20/90
# 303/303 [==============================] - 147s 486ms/step - loss: 2.4893 - acc: 0.2123 - val_loss: 3.5501 - val_acc: 0.1115
#
# Epoch 00020: val_acc did not improve from 0.12639
# Epoch 21/90
# 303/303 [==============================] - 147s 486ms/step - loss: 2.4247 - acc: 0.2219 - val_loss: 3.7184 - val_acc: 0.1190
#
# Epoch 00021: val_acc did not improve from 0.12639
# Epoch 22/90
# 303/303 [==============================] - 149s 491ms/step - loss: 2.3983 - acc: 0.2449 - val_loss: 3.6908 - val_acc: 0.1059
#
# Epoch 00022: val_acc did not improve from 0.12639
# Epoch 00022: early stopping
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_lst_m2d_6 (ConvLSTM2D)  (None, 50, 16, 16, 64)    266496
# _________________________________________________________________
# activation_15 (Activation)   (None, 50, 16, 16, 64)    0
# _________________________________________________________________
# time_distributed_6 (TimeDist (None, 50, 8, 8, 64)      0
# _________________________________________________________________
# conv_lst_m2d_7 (ConvLSTM2D)  (None, 50, 5, 5, 64)      524544
# _________________________________________________________________
# activation_16 (Activation)   (None, 50, 5, 5, 64)      0
# _________________________________________________________________
# time_distributed_7 (TimeDist (None, 50, 1, 1, 64)      0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 3200)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 960)               3072960
# _________________________________________________________________
# activation_17 (Activation)   (None, 960)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 480)               461280
# _________________________________________________________________
# activation_18 (Activation)   (None, 480)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 240)               115440
# _________________________________________________________________
# activation_19 (Activation)   (None, 240)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 27)                6507
# =================================================================
# Total params: 4,447,227
# Trainable params: 4,447,227
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/90
# 303/303 [==============================] - 153s 490ms/step - loss: 3.3996 - acc: 0.0313 - val_loss: 3.2986 - val_acc: 0.0279
#
# Epoch 00001: val_acc improved from -inf to 0.02788, saving model to ML_team1.h5
# Epoch 2/90
# 303/303 [==============================] - 149s 491ms/step - loss: 3.2920 - acc: 0.0362 - val_loss: 3.2034 - val_acc: 0.1022
#
# Epoch 00002: val_acc improved from 0.02788 to 0.10223, saving model to ML_team1.h5
# Epoch 3/90
# 303/303 [==============================] - 148s 488ms/step - loss: 3.2191 - acc: 0.0786 - val_loss: 3.1847 - val_acc: 0.0967
#
# Epoch 00003: val_acc did not improve from 0.10223
# Epoch 4/90
# 303/303 [==============================] - 146s 481ms/step - loss: 3.1926 - acc: 0.0842 - val_loss: 3.1536 - val_acc: 0.1078
#
# Epoch 00004: val_acc improved from 0.10223 to 0.10781, saving model to ML_team1.h5
# Epoch 5/90
# 303/303 [==============================] - 147s 484ms/step - loss: 3.1632 - acc: 0.0916 - val_loss: 3.2284 - val_acc: 0.0948
#
# Epoch 00005: val_acc did not improve from 0.10781
# Epoch 6/90
# 303/303 [==============================] - 147s 485ms/step - loss: 3.1768 - acc: 0.0895 - val_loss: 3.1770 - val_acc: 0.0799
#
# Epoch 00006: val_acc did not improve from 0.10781
# Epoch 7/90
# 303/303 [==============================] - 147s 485ms/step - loss: 3.1557 - acc: 0.0884 - val_loss: 3.1560 - val_acc: 0.1134
#
# Epoch 00007: val_acc improved from 0.10781 to 0.11338, saving model to ML_team1.h5
# Epoch 8/90
# 303/303 [==============================] - 147s 486ms/step - loss: 3.1349 - acc: 0.0889 - val_loss: 3.1676 - val_acc: 0.0892
#
# Epoch 00008: val_acc did not improve from 0.11338
# Epoch 9/90
# 303/303 [==============================] - 147s 486ms/step - loss: 3.1059 - acc: 0.1048 - val_loss: 3.2264 - val_acc: 0.0836
#
# Epoch 00009: val_acc did not improve from 0.11338
# Epoch 10/90
# 303/303 [==============================] - 148s 487ms/step - loss: 3.1003 - acc: 0.1009 - val_loss: 3.1990 - val_acc: 0.1022
#
# Epoch 00010: val_acc did not improve from 0.11338
# Epoch 11/90
# 303/303 [==============================] - 148s 490ms/step - loss: 3.0613 - acc: 0.1111 - val_loss: 3.1641 - val_acc: 0.1078
#
# Epoch 00011: val_acc did not improve from 0.11338
# Epoch 12/90
# 303/303 [==============================] - 147s 486ms/step - loss: 3.0100 - acc: 0.1150 - val_loss: 3.1614 - val_acc: 0.1041
#
# Epoch 00012: val_acc did not improve from 0.11338
# Epoch 13/90
# 303/303 [==============================] - 147s 487ms/step - loss: 2.9905 - acc: 0.1122 - val_loss: 3.1247 - val_acc: 0.1227
#
# Epoch 00013: val_acc improved from 0.11338 to 0.12268, saving model to ML_team1.h5
# Epoch 14/90
# 303/303 [==============================] - 149s 491ms/step - loss: 2.9683 - acc: 0.1276 - val_loss: 3.1395 - val_acc: 0.1264
#
# Epoch 00014: val_acc improved from 0.12268 to 0.12639, saving model to ML_team1.h5
# Epoch 15/90
# 303/303 [==============================] - 149s 491ms/step - loss: 2.9502 - acc: 0.1354 - val_loss: 3.1368 - val_acc: 0.1115
#
# Epoch 00015: val_acc did not improve from 0.12639
# Epoch 16/90
# 303/303 [==============================] - 149s 492ms/step - loss: 2.9024 - acc: 0.1457 - val_loss: 3.0829 - val_acc: 0.1227
#
# Epoch 00016: val_acc did not improve from 0.12639
# Epoch 17/90
# 303/303 [==============================] - 149s 492ms/step - loss: 2.8793 - acc: 0.1380 - val_loss: 3.0999 - val_acc: 0.1097
#
# Epoch 00017: val_acc did not improve from 0.12639
# Epoch 18/90
# 303/303 [==============================] - 149s 491ms/step - loss: 2.8365 - acc: 0.1557 - val_loss: 3.1969 - val_acc: 0.1320
#
# Epoch 00018: val_acc improved from 0.12639 to 0.13197, saving model to ML_team1.h5
# Epoch 19/90
# 303/303 [==============================] - 149s 492ms/step - loss: 2.8015 - acc: 0.1584 - val_loss: 3.2005 - val_acc: 0.1227
#
# Epoch 00019: val_acc did not improve from 0.13197
# Epoch 20/90
# 303/303 [==============================] - 149s 490ms/step - loss: 2.7696 - acc: 0.1721 - val_loss: 3.2973 - val_acc: 0.1004
#
# Epoch 00020: val_acc did not improve from 0.13197
# Epoch 21/90
# 303/303 [==============================] - 147s 486ms/step - loss: 2.7134 - acc: 0.1769 - val_loss: 3.2903 - val_acc: 0.0967
#
# Epoch 00021: val_acc did not improve from 0.13197
# Epoch 22/90
# 303/303 [==============================] - 147s 484ms/step - loss: 2.6586 - acc: 0.1789 - val_loss: 3.2546 - val_acc: 0.1264
#
# Epoch 00022: val_acc did not improve from 0.13197
# Epoch 23/90
# 303/303 [==============================] - 147s 487ms/step - loss: 2.6059 - acc: 0.2004 - val_loss: 3.4656 - val_acc: 0.0967
#
# Epoch 00023: val_acc did not improve from 0.13197
# Epoch 24/90
# 303/303 [==============================] - 148s 488ms/step - loss: 2.5599 - acc: 0.2083 - val_loss: 3.5095 - val_acc: 0.1190
#
# Epoch 00024: val_acc did not improve from 0.13197
# Epoch 25/90
# 303/303 [==============================] - 148s 488ms/step - loss: 2.4839 - acc: 0.2216 - val_loss: 3.8940 - val_acc: 0.1097
#
# Epoch 00025: val_acc did not improve from 0.13197
# Epoch 26/90
# 303/303 [==============================] - 148s 488ms/step - loss: 2.4570 - acc: 0.2348 - val_loss: 3.8578 - val_acc: 0.1041
#
# Epoch 00026: val_acc did not improve from 0.13197
# Epoch 27/90
# 303/303 [==============================] - 148s 488ms/step - loss: 2.4231 - acc: 0.2396 - val_loss: 3.6696 - val_acc: 0.0985
#
# Epoch 00027: val_acc did not improve from 0.13197
# Epoch 28/90
# 303/303 [==============================] - 147s 485ms/step - loss: 2.3100 - acc: 0.2667 - val_loss: 3.9972 - val_acc: 0.1097
#
# Epoch 00028: val_acc did not improve from 0.13197
# Epoch 00028: early stopping
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_lst_m2d_8 (ConvLSTM2D)  (None, 50, 16, 16, 64)    266496
# _________________________________________________________________
# activation_20 (Activation)   (None, 50, 16, 16, 64)    0
# _________________________________________________________________
# time_distributed_8 (TimeDist (None, 50, 8, 8, 64)      0
# _________________________________________________________________
# conv_lst_m2d_9 (ConvLSTM2D)  (None, 50, 5, 5, 64)      524544
# _________________________________________________________________
# activation_21 (Activation)   (None, 50, 5, 5, 64)      0
# _________________________________________________________________
# time_distributed_9 (TimeDist (None, 50, 1, 1, 64)      0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 3200)              0
# _________________________________________________________________
# dense_16 (Dense)             (None, 960)               3072960
# _________________________________________________________________
# activation_22 (Activation)   (None, 960)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 480)               461280
# _________________________________________________________________
# activation_23 (Activation)   (None, 480)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 240)               115440
# _________________________________________________________________
# activation_24 (Activation)   (None, 240)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 27)                6507
# =================================================================
# Total params: 4,447,227
# Trainable params: 4,447,227
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/90
# 303/303 [==============================] - 153s 490ms/step - loss: 3.3358 - acc: 0.0373 - val_loss: 3.2964 - val_acc: 0.0390
#
# Epoch 00001: val_acc improved from -inf to 0.03903, saving model to ML_team1.h5
# Epoch 2/90
# 303/303 [==============================] - 148s 488ms/step - loss: 3.2940 - acc: 0.0467 - val_loss: 3.2388 - val_acc: 0.1022
#
# Epoch 00002: val_acc improved from 0.03903 to 0.10223, saving model to ML_team1.h5
# Epoch 3/90
# 303/303 [==============================] - 148s 488ms/step - loss: 3.2365 - acc: 0.0779 - val_loss: 3.4248 - val_acc: 0.0985
#
# Epoch 00003: val_acc did not improve from 0.10223
# Epoch 4/90
# 303/303 [==============================] - 148s 488ms/step - loss: 3.1978 - acc: 0.0786 - val_loss: 3.1431 - val_acc: 0.1004
#
# Epoch 00004: val_acc did not improve from 0.10223
# Epoch 5/90
# 303/303 [==============================] - 152s 502ms/step - loss: 3.1599 - acc: 0.0803 - val_loss: 3.1484 - val_acc: 0.1152
#
# Epoch 00005: val_acc improved from 0.10223 to 0.11524, saving model to ML_team1.h5
# Epoch 6/90
# 303/303 [==============================] - 156s 514ms/step - loss: 3.1218 - acc: 0.0954 - val_loss: 3.1173 - val_acc: 0.1041
#
# Epoch 00006: val_acc did not improve from 0.11524
# Epoch 7/90
# 303/303 [==============================] - 152s 502ms/step - loss: 3.0882 - acc: 0.0985 - val_loss: 3.1875 - val_acc: 0.0985
#
# Epoch 00007: val_acc did not improve from 0.11524
# Epoch 8/90
# 303/303 [==============================] - 147s 485ms/step - loss: 3.0631 - acc: 0.1010 - val_loss: 3.1356 - val_acc: 0.0967
#
# Epoch 00008: val_acc did not improve from 0.11524
# Epoch 9/90
# 303/303 [==============================] - 142s 469ms/step - loss: 2.9897 - acc: 0.1194 - val_loss: 3.1601 - val_acc: 0.1041
#
# Epoch 00009: val_acc did not improve from 0.11524
# Epoch 10/90
# 303/303 [==============================] - 143s 471ms/step - loss: 2.9797 - acc: 0.1161 - val_loss: 3.0991 - val_acc: 0.1059
#
# Epoch 00010: val_acc did not improve from 0.11524
# Epoch 11/90
# 303/303 [==============================] - 142s 469ms/step - loss: 2.9367 - acc: 0.1357 - val_loss: 3.2579 - val_acc: 0.0967
#
# Epoch 00011: val_acc did not improve from 0.11524
# Epoch 12/90
# 303/303 [==============================] - 142s 470ms/step - loss: 2.8870 - acc: 0.1405 - val_loss: 3.1391 - val_acc: 0.1097
#
# Epoch 00012: val_acc did not improve from 0.11524
# Epoch 13/90
# 303/303 [==============================] - 142s 468ms/step - loss: 2.8496 - acc: 0.1495 - val_loss: 3.2389 - val_acc: 0.1041
#
# Epoch 00013: val_acc did not improve from 0.11524
# Epoch 14/90
# 303/303 [==============================] - 141s 466ms/step - loss: 2.7839 - acc: 0.1518 - val_loss: 3.2183 - val_acc: 0.1097
#
# Epoch 00014: val_acc did not improve from 0.11524
# Epoch 15/90
# 303/303 [==============================] - 142s 467ms/step - loss: 2.7266 - acc: 0.1498 - val_loss: 3.1102 - val_acc: 0.1227
#
# Epoch 00015: val_acc improved from 0.11524 to 0.12268, saving model to ML_team1.h5
# Epoch 16/90
# 303/303 [==============================] - 145s 478ms/step - loss: 2.6932 - acc: 0.1705 - val_loss: 3.2411 - val_acc: 0.1208
#
# Epoch 00016: val_acc did not improve from 0.12268
# Epoch 17/90
# 303/303 [==============================] - 153s 504ms/step - loss: 2.6125 - acc: 0.1904 - val_loss: 3.3559 - val_acc: 0.1152
#
# Epoch 00017: val_acc did not improve from 0.12268
# Epoch 18/90
# 303/303 [==============================] - 152s 502ms/step - loss: 2.5540 - acc: 0.2074 - val_loss: 3.6646 - val_acc: 0.1357
#
# Epoch 00018: val_acc improved from 0.12268 to 0.13569, saving model to ML_team1.h5
# Epoch 19/90
# 303/303 [==============================] - 153s 505ms/step - loss: 2.4744 - acc: 0.2302 - val_loss: 3.7883 - val_acc: 0.0948
#
# Epoch 00019: val_acc did not improve from 0.13569
# Epoch 20/90
# 303/303 [==============================] - 155s 512ms/step - loss: 2.4102 - acc: 0.2410 - val_loss: 3.7992 - val_acc: 0.1022
#
# Epoch 00020: val_acc did not improve from 0.13569
# Epoch 21/90
# 303/303 [==============================] - 154s 509ms/step - loss: 2.2975 - acc: 0.2616 - val_loss: 3.7979 - val_acc: 0.1152
#
# Epoch 00021: val_acc did not improve from 0.13569
# Epoch 22/90
# 303/303 [==============================] - 155s 512ms/step - loss: 2.2110 - acc: 0.2887 - val_loss: 3.7089 - val_acc: 0.1431
#
# Epoch 00022: val_acc improved from 0.13569 to 0.14312, saving model to ML_team1.h5
# Epoch 00022: early stopping
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_lst_m2d_10 (ConvLSTM2D) (None, 50, 16, 16, 64)    266496
# _________________________________________________________________
# activation_25 (Activation)   (None, 50, 16, 16, 64)    0
# _________________________________________________________________
# time_distributed_10 (TimeDis (None, 50, 8, 8, 64)      0
# _________________________________________________________________
# conv_lst_m2d_11 (ConvLSTM2D) (None, 50, 5, 5, 64)      524544
# _________________________________________________________________
# activation_26 (Activation)   (None, 50, 5, 5, 64)      0
# _________________________________________________________________
# time_distributed_11 (TimeDis (None, 50, 1, 1, 64)      0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 3200)              0
# _________________________________________________________________
# dense_20 (Dense)             (None, 960)               3072960
# _________________________________________________________________
# activation_27 (Activation)   (None, 960)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 480)               461280
# _________________________________________________________________
# activation_28 (Activation)   (None, 480)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 240)               115440
# _________________________________________________________________
# activation_29 (Activation)   (None, 240)               0
# _________________________________________________________________
# dense_23 (Dense)             (None, 27)                6507
# =================================================================
# Total params: 4,447,227
# Trainable params: 4,447,227
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/90
# 303/303 [==============================] - 160s 510ms/step - loss: 3.3179 - acc: 0.0351 - val_loss: 3.2971 - val_acc: 0.0372
#
# Epoch 00001: val_acc improved from -inf to 0.03717, saving model to ML_team1.h5
# Epoch 2/90
# 303/303 [==============================] - 154s 507ms/step - loss: 3.2718 - acc: 0.0545 - val_loss: 3.2087 - val_acc: 0.0911
#
# Epoch 00002: val_acc improved from 0.03717 to 0.09108, saving model to ML_team1.h5
# Epoch 3/90
# 303/303 [==============================] - 155s 511ms/step - loss: 3.2131 - acc: 0.0770 - val_loss: 3.1775 - val_acc: 0.1022
#
# Epoch 00003: val_acc improved from 0.09108 to 0.10223, saving model to ML_team1.h5
# Epoch 4/90
# 303/303 [==============================] - 152s 501ms/step - loss: 3.1822 - acc: 0.0852 - val_loss: 3.1786 - val_acc: 0.0874
#
# Epoch 00004: val_acc did not improve from 0.10223
# Epoch 5/90
# 303/303 [==============================] - 154s 508ms/step - loss: 3.1688 - acc: 0.0915 - val_loss: 3.2469 - val_acc: 0.0874
#
# Epoch 00005: val_acc did not improve from 0.10223
# Epoch 6/90
# 303/303 [==============================] - 157s 517ms/step - loss: 3.1522 - acc: 0.0899 - val_loss: 3.2851 - val_acc: 0.0688
#
# Epoch 00006: val_acc did not improve from 0.10223
# Epoch 7/90
# 303/303 [==============================] - 153s 506ms/step - loss: 3.1091 - acc: 0.0945 - val_loss: 3.6139 - val_acc: 0.0446
#
# Epoch 00007: val_acc did not improve from 0.10223
# Epoch 8/90
# 303/303 [==============================] - 153s 504ms/step - loss: 3.1056 - acc: 0.0912 - val_loss: 3.1685 - val_acc: 0.1059
#
# Epoch 00008: val_acc improved from 0.10223 to 0.10595, saving model to ML_team1.h5
# Epoch 9/90
# 303/303 [==============================] - 153s 506ms/step - loss: 3.0751 - acc: 0.1002 - val_loss: 3.1556 - val_acc: 0.1041
#
# Epoch 00009: val_acc did not improve from 0.10595
# Epoch 10/90
# 303/303 [==============================] - 152s 503ms/step - loss: 3.0383 - acc: 0.1093 - val_loss: 3.2116 - val_acc: 0.1078
#
# Epoch 00010: val_acc improved from 0.10595 to 0.10781, saving model to ML_team1.h5
# Epoch 11/90
# 303/303 [==============================] - 152s 502ms/step - loss: 3.0215 - acc: 0.1120 - val_loss: 3.2266 - val_acc: 0.0892
#
# Epoch 00011: val_acc did not improve from 0.10781
# Epoch 12/90
# 303/303 [==============================] - 151s 498ms/step - loss: 2.9717 - acc: 0.1224 - val_loss: 3.0656 - val_acc: 0.1115
#
# Epoch 00012: val_acc improved from 0.10781 to 0.11152, saving model to ML_team1.h5
# Epoch 13/90
# 303/303 [==============================] - 150s 496ms/step - loss: 2.9285 - acc: 0.1366 - val_loss: 3.0773 - val_acc: 0.1059
#
# Epoch 00013: val_acc did not improve from 0.11152
# Epoch 14/90
# 303/303 [==============================] - 150s 496ms/step - loss: 2.9274 - acc: 0.1225 - val_loss: 3.2035 - val_acc: 0.0799
#
# Epoch 00014: val_acc did not improve from 0.11152
# Epoch 15/90
# 303/303 [==============================] - 150s 495ms/step - loss: 2.8880 - acc: 0.1411 - val_loss: 3.1897 - val_acc: 0.1078
#
# Epoch 00015: val_acc did not improve from 0.11152
# Epoch 16/90
# 303/303 [==============================] - 150s 494ms/step - loss: 2.8327 - acc: 0.1410 - val_loss: 3.1013 - val_acc: 0.1264
#
# Epoch 00016: val_acc improved from 0.11152 to 0.12639, saving model to ML_team1.h5
# Epoch 17/90
# 303/303 [==============================] - 150s 495ms/step - loss: 2.7981 - acc: 0.1610 - val_loss: 3.4172 - val_acc: 0.0948
#
# Epoch 00017: val_acc did not improve from 0.12639
# Epoch 18/90
# 303/303 [==============================] - 149s 492ms/step - loss: 2.7628 - acc: 0.1682 - val_loss: 3.1467 - val_acc: 0.1152
#
# Epoch 00018: val_acc did not improve from 0.12639
# Epoch 19/90
# 303/303 [==============================] - 147s 487ms/step - loss: 2.7213 - acc: 0.1685 - val_loss: 3.1451 - val_acc: 0.1152
#
# Epoch 00019: val_acc did not improve from 0.12639
# Epoch 20/90
# 303/303 [==============================] - 147s 485ms/step - loss: 2.6682 - acc: 0.1799 - val_loss: 3.3590 - val_acc: 0.1022
#
# Epoch 00020: val_acc did not improve from 0.12639
# Epoch 21/90
# 303/303 [==============================] - 148s 490ms/step - loss: 2.6286 - acc: 0.1972 - val_loss: 3.3762 - val_acc: 0.0948
#
# Epoch 00021: val_acc did not improve from 0.12639
# Epoch 22/90
# 303/303 [==============================] - 149s 490ms/step - loss: 2.5512 - acc: 0.2257 - val_loss: 3.4515 - val_acc: 0.1245
#
# Epoch 00022: val_acc did not improve from 0.12639
# Epoch 23/90
# 303/303 [==============================] - 149s 493ms/step - loss: 2.4492 - acc: 0.2428 - val_loss: 3.4362 - val_acc: 0.1134
#
# Epoch 00023: val_acc did not improve from 0.12639
# Epoch 24/90
# 303/303 [==============================] - 150s 497ms/step - loss: 2.3970 - acc: 0.2589 - val_loss: 3.5937 - val_acc: 0.1004
#
# Epoch 00024: val_acc did not improve from 0.12639
# Epoch 00024: early stopping
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_lst_m2d_12 (ConvLSTM2D) (None, 50, 16, 16, 64)    266496
# _________________________________________________________________
# activation_30 (Activation)   (None, 50, 16, 16, 64)    0
# _________________________________________________________________
# time_distributed_12 (TimeDis (None, 50, 8, 8, 64)      0
# _________________________________________________________________
# conv_lst_m2d_13 (ConvLSTM2D) (None, 50, 5, 5, 64)      524544
# _________________________________________________________________
# activation_31 (Activation)   (None, 50, 5, 5, 64)      0
# _________________________________________________________________
# time_distributed_13 (TimeDis (None, 50, 1, 1, 64)      0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 3200)              0
# _________________________________________________________________
# dense_24 (Dense)             (None, 960)               3072960
# _________________________________________________________________
# activation_32 (Activation)   (None, 960)               0
# _________________________________________________________________
# dense_25 (Dense)             (None, 480)               461280
# _________________________________________________________________
# activation_33 (Activation)   (None, 480)               0
# _________________________________________________________________
# dense_26 (Dense)             (None, 240)               115440
# _________________________________________________________________
# activation_34 (Activation)   (None, 240)               0
# _________________________________________________________________
# dense_27 (Dense)             (None, 27)                6507
# =================================================================
# Total params: 4,447,227
# Trainable params: 4,447,227
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/90
# 303/303 [==============================] - 155s 497ms/step - loss: 3.5605 - acc: 0.0335 - val_loss: 3.3019 - val_acc: 0.0242
#
# Epoch 00001: val_acc improved from -inf to 0.02416, saving model to ML_team1.h5
# Epoch 2/90
# 303/303 [==============================] - 150s 493ms/step - loss: 3.2793 - acc: 0.0567 - val_loss: 3.2324 - val_acc: 0.0836
#
# Epoch 00002: val_acc improved from 0.02416 to 0.08364, saving model to ML_team1.h5
# Epoch 3/90
# 303/303 [==============================] - 149s 493ms/step - loss: 3.2197 - acc: 0.0822 - val_loss: 3.1682 - val_acc: 0.0818
#
# Epoch 00003: val_acc did not improve from 0.08364
# Epoch 4/90
# 303/303 [==============================] - 150s 494ms/step - loss: 3.1908 - acc: 0.0802 - val_loss: 3.1540 - val_acc: 0.1097
#
# Epoch 00004: val_acc improved from 0.08364 to 0.10967, saving model to ML_team1.h5
# Epoch 5/90
# 303/303 [==============================] - 149s 492ms/step - loss: 3.1674 - acc: 0.0890 - val_loss: 3.1347 - val_acc: 0.1004
#
# Epoch 00005: val_acc did not improve from 0.10967
# Epoch 6/90
# 303/303 [==============================] - 149s 492ms/step - loss: 3.1279 - acc: 0.0954 - val_loss: 3.1748 - val_acc: 0.0967
#
# Epoch 00006: val_acc did not improve from 0.10967
# Epoch 7/90
# 303/303 [==============================] - 149s 490ms/step - loss: 3.0812 - acc: 0.1046 - val_loss: 3.2843 - val_acc: 0.0948
#
# Epoch 00007: val_acc did not improve from 0.10967
# Epoch 8/90
# 303/303 [==============================] - 149s 493ms/step - loss: 3.0439 - acc: 0.1149 - val_loss: 3.0808 - val_acc: 0.1022
#
# Epoch 00008: val_acc did not improve from 0.10967
# Epoch 9/90
# 303/303 [==============================] - 149s 492ms/step - loss: 3.0436 - acc: 0.1058 - val_loss: 3.2068 - val_acc: 0.1190
#
# Epoch 00009: val_acc improved from 0.10967 to 0.11896, saving model to ML_team1.h5
# Epoch 10/90
# 303/303 [==============================] - 152s 503ms/step - loss: 2.9880 - acc: 0.1189 - val_loss: 3.0560 - val_acc: 0.1190
#
# Epoch 00010: val_acc did not improve from 0.11896
# Epoch 11/90
# 303/303 [==============================] - 155s 512ms/step - loss: 2.9572 - acc: 0.1299 - val_loss: 3.1107 - val_acc: 0.1320
#
# Epoch 00011: val_acc improved from 0.11896 to 0.13197, saving model to ML_team1.h5
# Epoch 12/90
# 303/303 [==============================] - 154s 510ms/step - loss: 2.9237 - acc: 0.1363 - val_loss: 3.0365 - val_acc: 0.1357
#
# Epoch 00012: val_acc improved from 0.13197 to 0.13569, saving model to ML_team1.h5
# Epoch 13/90
# 303/303 [==============================] - 151s 499ms/step - loss: 2.8772 - acc: 0.1457 - val_loss: 3.1258 - val_acc: 0.1134
#
# Epoch 00013: val_acc did not improve from 0.13569
# Epoch 14/90
# 303/303 [==============================] - 150s 494ms/step - loss: 2.8326 - acc: 0.1495 - val_loss: 3.2017 - val_acc: 0.0929
#
# Epoch 00014: val_acc did not improve from 0.13569
# Epoch 15/90
# 303/303 [==============================] - 145s 479ms/step - loss: 2.7939 - acc: 0.1474 - val_loss: 3.0736 - val_acc: 0.1264
#
# Epoch 00015: val_acc did not improve from 0.13569
# Epoch 16/90
# 303/303 [==============================] - 144s 474ms/step - loss: 2.7290 - acc: 0.1666 - val_loss: 3.3755 - val_acc: 0.1283
#
# Epoch 00016: val_acc did not improve from 0.13569
# Epoch 17/90
# 303/303 [==============================] - 145s 478ms/step - loss: 2.6976 - acc: 0.1700 - val_loss: 3.5023 - val_acc: 0.1134
#
# Epoch 00017: val_acc did not improve from 0.13569
# Epoch 18/90
# 303/303 [==============================] - 144s 474ms/step - loss: 2.6214 - acc: 0.1863 - val_loss: 3.2157 - val_acc: 0.1190
#
# Epoch 00018: val_acc did not improve from 0.13569
# Epoch 19/90
# 303/303 [==============================] - 143s 474ms/step - loss: 2.5443 - acc: 0.2135 - val_loss: 3.4590 - val_acc: 0.1171
#
# Epoch 00019: val_acc did not improve from 0.13569
# Epoch 20/90
# 303/303 [==============================] - 144s 476ms/step - loss: 2.4998 - acc: 0.2170 - val_loss: 3.2915 - val_acc: 0.1487
#
# Epoch 00020: val_acc improved from 0.13569 to 0.14870, saving model to ML_team1.h5
# Epoch 21/90
# 303/303 [==============================] - 145s 477ms/step - loss: 2.4148 - acc: 0.2366 - val_loss: 3.3942 - val_acc: 0.1208
#
# Epoch 00021: val_acc did not improve from 0.14870
# Epoch 22/90
# 303/303 [==============================] - 144s 476ms/step - loss: 2.3355 - acc: 0.2609 - val_loss: 3.6935 - val_acc: 0.1134
#
# Epoch 00022: val_acc did not improve from 0.14870
# Epoch 23/90
# ...
#
# Epoch 00006: val_acc did not improve from 0.10409
# Epoch 7/90
# 303/303 [==============================] - 143s 472ms/step - loss: 3.0966 - acc: 0.1007 - val_loss: 3.2563 - val_acc: 0.0781
#
# Epoch 00007: val_acc did not improve from 0.10409
# Epoch 8/90
# 303/303 [==============================] - 143s 470ms/step - loss: 3.0599 - acc: 0.1100 - val_loss: 3.0757 - val_acc: 0.1208
#
# Epoch 00008: val_acc improved from 0.10409 to 0.12082, saving model to ML_team1.h5
# Epoch 9/90
# 303/303 [==============================] - 142s 469ms/step - loss: 3.0120 - acc: 0.1124 - val_loss: 3.3890 - val_acc: 0.0799
#
# Epoch 00009: val_acc did not improve from 0.12082
# Epoch 10/90
# 303/303 [==============================] - 142s 469ms/step - loss: 2.9708 - acc: 0.1250 - val_loss: 3.1309 - val_acc: 0.1134
#
# Epoch 00010: val_acc did not improve from 0.12082
# Epoch 11/90
# 303/303 [==============================] - 143s 473ms/step - loss: 2.9346 - acc: 0.1220 - val_loss: 3.0403 - val_acc: 0.1171
#
# Epoch 00011: val_acc did not improve from 0.12082
# Epoch 12/90
# 303/303 [==============================] - 145s 478ms/step - loss: 2.9213 - acc: 0.1293 - val_loss: 3.2041 - val_acc: 0.1115
#
# Epoch 00012: val_acc did not improve from 0.12082
# Epoch 13/90
# 303/303 [==============================] - 146s 482ms/step - loss: 2.8648 - acc: 0.1320 - val_loss: 3.1308 - val_acc: 0.1004
#
# Epoch 00013: val_acc did not improve from 0.12082
# Epoch 14/90
# 303/303 [==============================] - 145s 479ms/step - loss: 2.8205 - acc: 0.1426 - val_loss: 3.1399 - val_acc: 0.1283
#
# Epoch 00014: val_acc improved from 0.12082 to 0.12825, saving model to ML_team1.h5
# Epoch 15/90
# 303/303 [==============================] - 145s 479ms/step - loss: 2.7638 - acc: 0.1720 - val_loss: 3.0627 - val_acc: 0.1320
#
# Epoch 00015: val_acc improved from 0.12825 to 0.13197, saving model to ML_team1.h5
# Epoch 16/90
# 303/303 [==============================] - 147s 486ms/step - loss: 2.7060 - acc: 0.1689 - val_loss: 3.3678 - val_acc: 0.0948
#
# Epoch 00016: val_acc did not improve from 0.13197
# Epoch 17/90
# 303/303 [==============================] - 147s 487ms/step - loss: 2.6278 - acc: 0.1929 - val_loss: 3.3109 - val_acc: 0.1171
#
# Epoch 00017: val_acc did not improve from 0.13197
# Epoch 18/90
# 303/303 [==============================] - 147s 484ms/step - loss: 2.5976 - acc: 0.1854 - val_loss: 3.3441 - val_acc: 0.1004
#
# Epoch 00018: val_acc did not improve from 0.13197
# Epoch 19/90
# 303/303 [==============================] - 147s 485ms/step - loss: 2.4975 - acc: 0.2124 - val_loss: 3.3983 - val_acc: 0.1245
#
# Epoch 00019: val_acc did not improve from 0.13197
# Epoch 20/90
# 303/303 [==============================] - 147s 485ms/step - loss: 2.4856 - acc: 0.2161 - val_loss: 3.6732 - val_acc: 0.1115
#
# Epoch 00020: val_acc did not improve from 0.13197
# Epoch 21/90
# 303/303 [==============================] - 147s 484ms/step - loss: 2.3987 - acc: 0.2415 - val_loss: 3.8456 - val_acc: 0.0836
#
# Epoch 00021: val_acc did not improve from 0.13197
# Epoch 22/90
# 303/303 [==============================] - 143s 471ms/step - loss: 2.3013 - acc: 0.2636 - val_loss: 3.8419 - val_acc: 0.1041
#
# Epoch 00022: val_acc did not improve from 0.13197
# Epoch 23/90
# 303/303 [==============================] - 143s 471ms/step - loss: 2.2055 - acc: 0.2939 - val_loss: 3.8685 - val_acc: 0.1264
#
# Epoch 00023: val_acc did not improve from 0.13197
# Epoch 00023: early stopping
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_lst_m2d_16 (ConvLSTM2D) (None, 50, 16, 16, 64)    266496
# _________________________________________________________________
# activation_40 (Activation)   (None, 50, 16, 16, 64)    0
# _________________________________________________________________
# time_distributed_16 (TimeDis (None, 50, 8, 8, 64)      0
# _________________________________________________________________
# conv_lst_m2d_17 (ConvLSTM2D) (None, 50, 5, 5, 64)      524544
# _________________________________________________________________
# activation_41 (Activation)   (None, 50, 5, 5, 64)      0
# _________________________________________________________________
# time_distributed_17 (TimeDis (None, 50, 1, 1, 64)      0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 3200)              0
# _________________________________________________________________
# dense_32 (Dense)             (None, 960)               3072960
# _________________________________________________________________
# activation_42 (Activation)   (None, 960)               0
# _________________________________________________________________
# dense_33 (Dense)             (None, 480)               461280
# _________________________________________________________________
# activation_43 (Activation)   (None, 480)               0
# _________________________________________________________________
# dense_34 (Dense)             (None, 240)               115440
# _________________________________________________________________
# activation_44 (Activation)   (None, 240)               0
# _________________________________________________________________
# dense_35 (Dense)             (None, 27)                6507
# =================================================================
# Total params: 4,447,227
# Trainable params: 4,447,227
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/90
# 303/303 [==============================] - 148s 473ms/step - loss: 3.4097 - acc: 0.0329 - val_loss: 3.2871 - val_acc: 0.0669
#
# Epoch 00001: val_acc improved from -inf to 0.06691, saving model to ML_team1.h5
# Epoch 2/90
# 303/303 [==============================] - 143s 471ms/step - loss: 3.2838 - acc: 0.0667 - val_loss: 3.2173 - val_acc: 0.1022
#
# Epoch 00002: val_acc improved from 0.06691 to 0.10223, saving model to ML_team1.h5
# Epoch 3/90
# 303/303 [==============================] - 143s 471ms/step - loss: 3.2274 - acc: 0.0774 - val_loss: 3.1661 - val_acc: 0.0911
#
# Epoch 00003: val_acc did not improve from 0.10223
# Epoch 4/90
# 303/303 [==============================] - 143s 471ms/step - loss: 3.1557 - acc: 0.0873 - val_loss: 3.1908 - val_acc: 0.0874
#
# Epoch 00004: val_acc did not improve from 0.10223
# Epoch 5/90
# 303/303 [==============================] - 143s 472ms/step - loss: 3.1577 - acc: 0.0963 - val_loss: 3.1944 - val_acc: 0.1078
#
# Epoch 00005: val_acc improved from 0.10223 to 0.10781, saving model to ML_team1.h5
# Epoch 6/90
# 303/303 [==============================] - 143s 470ms/step - loss: 3.1255 - acc: 0.0960 - val_loss: 3.1521 - val_acc: 0.1078
#
# Epoch 00006: val_acc did not improve from 0.10781
# Epoch 7/90
# 303/303 [==============================] - 143s 471ms/step - loss: 3.0857 - acc: 0.1016 - val_loss: 3.0804 - val_acc: 0.1078
#
# Epoch 00007: val_acc did not improve from 0.10781
# Epoch 8/90
# 303/303 [==============================] - 143s 473ms/step - loss: 3.0368 - acc: 0.1103 - val_loss: 3.0853 - val_acc: 0.1134
#
# Epoch 00008: val_acc improved from 0.10781 to 0.11338, saving model to ML_team1.h5
# Epoch 9/90
# 303/303 [==============================] - 146s 482ms/step - loss: 3.0215 - acc: 0.1165 - val_loss: 3.1345 - val_acc: 0.1227
#
# Epoch 00009: val_acc improved from 0.11338 to 0.12268, saving model to ML_team1.h5
# Epoch 10/90
# 303/303 [==============================] - 144s 476ms/step - loss: 2.9991 - acc: 0.1142 - val_loss: 3.3879 - val_acc: 0.0948
#
# Epoch 00010: val_acc did not improve from 0.12268
# Epoch 11/90
# 303/303 [==============================] - 146s 483ms/step - loss: 2.9498 - acc: 0.1237 - val_loss: 3.2142 - val_acc: 0.0967
#
# Epoch 00011: val_acc did not improve from 0.12268
# Epoch 12/90
# 303/303 [==============================] - 147s 485ms/step - loss: 2.8843 - acc: 0.1457 - val_loss: 3.5352 - val_acc: 0.0929
#
# Epoch 00012: val_acc did not improve from 0.12268
# Epoch 13/90
# 303/303 [==============================] - 148s 489ms/step - loss: 2.8595 - acc: 0.1485 - val_loss: 3.1083 - val_acc: 0.1059
#
# Epoch 00013: val_acc did not improve from 0.12268
# Epoch 14/90
# 303/303 [==============================] - 145s 477ms/step - loss: 2.8134 - acc: 0.1531 - val_loss: 3.0910 - val_acc: 0.1152
#
# Epoch 00014: val_acc did not improve from 0.12268
# Epoch 15/90
# 303/303 [==============================] - 145s 478ms/step - loss: 2.7540 - acc: 0.1640 - val_loss: 3.1992 - val_acc: 0.1097
#
# Epoch 00015: val_acc did not improve from 0.12268
# Epoch 16/90
# 303/303 [==============================] - 145s 477ms/step - loss: 2.7373 - acc: 0.1637 - val_loss: 3.1446 - val_acc: 0.1190
#
# Epoch 00016: val_acc did not improve from 0.12268
# Epoch 17/90
# 303/303 [==============================] - 144s 475ms/step - loss: 2.6734 - acc: 0.1827 - val_loss: 3.4808 - val_acc: 0.0948
#
# Epoch 00017: val_acc did not improve from 0.12268
# Epoch 18/90
# 303/303 [==============================] - 145s 479ms/step - loss: 2.6105 - acc: 0.1943 - val_loss: 4.0982 - val_acc: 0.0929
#
# Epoch 00018: val_acc did not improve from 0.12268
# Epoch 19/90
# 303/303 [==============================] - 145s 480ms/step - loss: 2.5633 - acc: 0.2095 - val_loss: 3.4666 - val_acc: 0.1078
#
# Epoch 00019: val_acc did not improve from 0.12268
# Epoch 00019: early stopping
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_lst_m2d_18 (ConvLSTM2D) (None, 50, 16, 16, 64)    266496
# _________________________________________________________________
# activation_45 (Activation)   (None, 50, 16, 16, 64)    0
# _________________________________________________________________
# time_distributed_18 (TimeDis (None, 50, 8, 8, 64)      0
# _________________________________________________________________
# conv_lst_m2d_19 (ConvLSTM2D) (None, 50, 5, 5, 64)      524544
# _________________________________________________________________
# activation_46 (Activation)   (None, 50, 5, 5, 64)      0
# _________________________________________________________________
# time_distributed_19 (TimeDis (None, 50, 1, 1, 64)      0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 3200)              0
# _________________________________________________________________
# dense_36 (Dense)             (None, 960)               3072960
# _________________________________________________________________
# activation_47 (Activation)   (None, 960)               0
# _________________________________________________________________
# dense_37 (Dense)             (None, 480)               461280
# _________________________________________________________________
# activation_48 (Activation)   (None, 480)               0
# _________________________________________________________________
# dense_38 (Dense)             (None, 240)               115440
# _________________________________________________________________
# activation_49 (Activation)   (None, 240)               0
# _________________________________________________________________
# dense_39 (Dense)             (None, 27)                6507
# =================================================================
# Total params: 4,447,227
# Trainable params: 4,447,227
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/90
# 303/303 [==============================] - 152s 486ms/step - loss: 3.3555 - acc: 0.0287 - val_loss: 3.2882 - val_acc: 0.0520
#
# Epoch 00001: val_acc improved from -inf to 0.05204, saving model to ML_team1.h5
# Epoch 2/90
# 303/303 [==============================] - 146s 483ms/step - loss: 3.2923 - acc: 0.0538 - val_loss: 3.1929 - val_acc: 0.0985
#
# Epoch 00002: val_acc improved from 0.05204 to 0.09851, saving model to ML_team1.h5
# Epoch 3/90
# 303/303 [==============================] - 147s 484ms/step - loss: 3.2280 - acc: 0.0761 - val_loss: 3.1671 - val_acc: 0.0892
#
# Epoch 00003: val_acc did not improve from 0.09851
# Epoch 4/90
# 303/303 [==============================] - 146s 483ms/step - loss: 3.1980 - acc: 0.0899 - val_loss: 3.2039 - val_acc: 0.0892
#
# Epoch 00004: val_acc did not improve from 0.09851
# Epoch 5/90
# 303/303 [==============================] - 146s 481ms/step - loss: 3.1779 - acc: 0.0862 - val_loss: 3.2067 - val_acc: 0.0967
#
# Epoch 00005: val_acc did not improve from 0.09851
# Epoch 6/90
# 303/303 [==============================] - 147s 485ms/step - loss: 3.1471 - acc: 0.0917 - val_loss: 3.5531 - val_acc: 0.0576
#
# Epoch 00006: val_acc did not improve from 0.09851
# Epoch 7/90
# 303/303 [==============================] - 146s 483ms/step - loss: 3.1028 - acc: 0.1006 - val_loss: 3.1247 - val_acc: 0.1208
#
# Epoch 00007: val_acc improved from 0.09851 to 0.12082, saving model to ML_team1.h5
# Epoch 8/90
# 303/303 [==============================] - 146s 483ms/step - loss: 3.1074 - acc: 0.0969 - val_loss: 3.1403 - val_acc: 0.0911
#
# Epoch 00008: val_acc did not improve from 0.12082
# Epoch 9/90
# 303/303 [==============================] - 146s 482ms/step - loss: 3.0670 - acc: 0.0978 - val_loss: 3.1479 - val_acc: 0.1245
#
# Epoch 00009: val_acc improved from 0.12082 to 0.12454, saving model to ML_team1.h5
# Epoch 10/90
# 303/303 [==============================] - 145s 479ms/step - loss: 3.0305 - acc: 0.1094 - val_loss: 3.0498 - val_acc: 0.1227
#
# Epoch 00010: val_acc did not improve from 0.12454
# Epoch 11/90
# 303/303 [==============================] - 146s 482ms/step - loss: 2.9902 - acc: 0.1194 - val_loss: 3.2356 - val_acc: 0.1283
#
# Epoch 00011: val_acc improved from 0.12454 to 0.12825, saving model to ML_team1.h5
# Epoch 12/90
# 303/303 [==============================] - 145s 480ms/step - loss: 2.9614 - acc: 0.1265 - val_loss: 3.6529 - val_acc: 0.1004
#
# Epoch 00012: val_acc did not improve from 0.12825
# Epoch 13/90
# 303/303 [==============================] - 147s 485ms/step - loss: 2.9337 - acc: 0.1392 - val_loss: 3.2293 - val_acc: 0.1059
#
# Epoch 00013: val_acc did not improve from 0.12825
# Epoch 14/90
# 303/303 [==============================] - 144s 474ms/step - loss: 2.9100 - acc: 0.1312 - val_loss: 3.0712 - val_acc: 0.1115
#
# Epoch 00014: val_acc did not improve from 0.12825
# Epoch 15/90
# 303/303 [==============================] - 144s 477ms/step - loss: 2.8646 - acc: 0.1323 - val_loss: 3.1473 - val_acc: 0.1059
#
# Epoch 00015: val_acc did not improve from 0.12825
# Epoch 16/90
# 303/303 [==============================] - 144s 475ms/step - loss: 2.8071 - acc: 0.1519 - val_loss: 3.1788 - val_acc: 0.1152
#
# Epoch 00016: val_acc did not improve from 0.12825
# Epoch 17/90
# 303/303 [==============================] - 149s 491ms/step - loss: 2.8034 - acc: 0.1633 - val_loss: 3.1957 - val_acc: 0.0929
#
# Epoch 00017: val_acc did not improve from 0.12825
# Epoch 18/90
# 303/303 [==============================] - 146s 481ms/step - loss: 2.7246 - acc: 0.1671 - val_loss: 3.3586 - val_acc: 0.0948
#
# Epoch 00018: val_acc did not improve from 0.12825
# Epoch 19/90
# 303/303 [==============================] - 148s 489ms/step - loss: 2.6975 - acc: 0.1748 - val_loss: 3.4516 - val_acc: 0.1357
#
# Epoch 00019: val_acc improved from 0.12825 to 0.13569, saving model to ML_team1.h5
# Epoch 20/90
# 303/303 [==============================] - 149s 493ms/step - loss: 2.6439 - acc: 0.1921 - val_loss: 3.4416 - val_acc: 0.1208
#
# Epoch 00020: val_acc did not improve from 0.13569
# Epoch 21/90
# 303/303 [==============================] - 152s 500ms/step - loss: 2.5802 - acc: 0.2024 - val_loss: 3.5145 - val_acc: 0.1190
#
# Epoch 00021: val_acc did not improve from 0.13569
# Epoch 22/90
# 303/303 [==============================] - 151s 498ms/step - loss: 2.5284 - acc: 0.2182 - val_loss: 3.8225 - val_acc: 0.1152
#
# Epoch 00022: val_acc did not improve from 0.13569
# Epoch 00022: early stopping

# %%
predict_result = (predict_list[0] + predict_list[1] + predict_list[2] +predict_list[3] +predict_list[4] +predict_list[5] +predict_list[6] +predict_list[7] +predict_list[8] + predict_list[9])/10
predict_label = []
for k in predict_result:        
    predict_label.append(k.argmax())

pred_test_label_txt = list_data = [str(rating[int(a)]).strip('\n\r') for a in predict_label]
print(pred_test_label_txt)
# Out:
# ['7d', '7k', '14k', '14k', '12k', '7d', '10k', '17k', '7d', '4k', '2d', '14k', '9k', '17k', '9k', '9d', '9k', '6k', '2d', '4d', '16k', '7d', '5k', '16k', '9k', '9d', '1k', '17k', '9k', '16k', '5d', '4k', '17k', '8d', '3d', '9d', '8d', '9d', '15k', '18k', '1d', '1d', '4d', '10k', '15k', '4k', '3k', '3d', '14k', '5d', '8k', '6k', '4k', '12k', '3k', '14k', '10k', '2d', '4k', '5d', '5k', '1d', '1k', '9k', '8d', '5d', '10k', '9k', '1d', '8d', '5k', '17k', '6d', '7d', '2d', '1d', '4d', '15k', '5d', '9d', '1d', '14k', '3k', '9d', '5d', '9d', '1d', '5d', '9k', '9d', '9k', '12k', '6k', '4k', '3k', '9d', '7d', '8d', '5k', '16k', '14k', '15k', '10k', '5k', '5k', '15k', '7d', '9d', '6k', '1d', '12k', '8d', '3k', '3k', '6d', '17k', '9d', '5d', '6k', '7d', '17k', '8d', '5k', '17k', '10k', '15k', '5d', '8d', '3k', '12k', '2k', '9d', '16k', '8d', '12k', '1d', '15k', '8d', '9k', '9d', '8d', '6k', '6k', '9d', '17k', '1d', '7d', '7d', '9k', '9k', '8d', '1k', '10k', '3k', '11k', '5d', '7d', '11k', '6k', '4k', '12k', '17k', '15k', '1k', '5d', '3k', '8k', '5d', '3k', '4k', '9d', '9d', '9k', '6d', '7k', '15k', '4d', '9k', '2d', '6d', '14k', '9k', '1d', '7d', '18k', '10k', '3k', '8d', '8d', '9k', '5d', '9k', '12k', '2d', '9d', '14k', '1k', '8k', '12k', '5k', '14k', '4k', '7d', '2d', '17k', '9d', '17k', '1d', '2k', '3d', '9k', '2d', '7k', '18k', '8k', '7d', '17k', '2k', '2d', '7k', '15k', '3k', '6d', '8k', '9d', '3k', '17k', '9d', '14k', '17k', '8d', '14k', '5k', '6k', '5k', '7d', '15k', '2d', '3k', '5d', '17k', '14k', '5d', '3k', '17k', '7k', '4d', '7d', '8d', '4k', '5d', '9k', '9k', '17k', '18k', '9k', '9d', '3d', '9d', '3d', '10k', '3k', '4k', '17k', '15k', '5d', '7k', '9k', '9d', '4k', '11k', '2k', '10k', '9k', '1d', '6k', '6k', '5k', '5d', '8d', '9k', '3k', '10k', '3d', '9d', '4k', '18k', '7d', '7d', '8d', '1k', '3k', '4d', '7k', '2d', '17k', '4d', '9d', '14k', '17k', '4d', '7d', '14k', '5d', '17k', '15k', '3k', '8d', '14k', '14k', '15k', '14k', '7d', '1d', '4d', '2k', '4d', '2k', '14k', '4d', '1k', '9k', '1d', '14k', '9d', '7k', '3k', '5d', '3d', '5d', '6k', '6k', '8d', '1d', '12k', '6d', '9d', '14k', '3k', '9d', '7d', '12k', '9d', '14k', '8d', '5k', '3k', '6d', '8d', '10k', '14k', '11k', '18k', '7k', '3d', '2k', '5d', '5d', '8d', '12k', '10k', '5d', '8d', '6k', '8d', '16k', '2d', '5d', '8d', '7d', '14k', '6k', '8d', '16k', '8k', '9k', '9k', '8d', '7d', '2k', '4d', '14k', '18k', '8k', '2k', '9d', '9k', '1d', '14k', '7k', '6k', '14k', '14k', '2k', '3k', '14k', '16k', '4d', '9d', '9k', '1d', '8d', '6d', '8d', '9d', '18k', '2k', '9d', '15k', '8d', '8d', '6d', '6k', '18k', '9k', '4d', '4k', '1k', '9d', '15k', '2k', '3k', '6d', '9k', '7d', '1d', '16k', '18k', '4k', '1d', '18k', '16k', '4k', '14k', '18k', '13k', '9k', '14k', '9k', '10k', '6k', '3d', '9d', '2d', '4d', '3k', '8d', '14k', '7k', '17k', '8d', '17k', '4d', '1k', '4k', '3d', '7d', '16k', '5d', '2d', '3k', '8d', '12k', '17k', '9d', '14k', '14k', '15k', '6k', '16k', '11k', '9d', '9k', '16k', '5d', '5k', '7d', '9d', '2d', '3k', '14k', '5d', '3k', '5k', '6k', '1d', '7d', '9d', '5d', '9d', '16k', '7d', '15k', '4d', '8d', '14k', '9k', '1d', '6k', '15k', '8d', '2k', '8d', '7d', '15k', '15k', '7d', '15k', '11k', '4d', '5k', '6k', '7d', '15k', '2k', '7k', '2k', '7d', '4k', '4d', '9d', '8d', '17k', '17k', '7d', '8d', '9d', '18k', '5d', '1d', '5d', '3k', '12k', '6d', '5k', '18k', '2k', '6d', '3k', '4k', '8d', '8d', '5d', '8k', '2d', '9d', '2d', '2k', '9k', '17k', '15k', '3d', '8d', '9d', '7d', '5d', '8d', '2k', '12k', '6k', '3d', '8k', '6k', '9k', '3k', '9d', '14k', '9k', '3d', '14k', '17k', '9d', '15k', '3d', '2k', '2d', '6k', '16k', '17k', '9k', '9d', '10k', '3d', '17k', '8d', '6k', '2d', '15k', '3k', '17k', '3k', '16k', '3k', '2k', '4k', '8d', '9d', '17k', '5k', '4d', '1k', '6k', '6k', '3d', '4k', '7k', '6k', '8d', '7k', '1k', '9d', '3k', '17k', '11k', '17k', '3k', '8d', '16k', '5k', '6d', '17k', '9d', '7d', '2k', '2k', '6k', '8k', '4k', '15k', '5d', '6d', '10k', '8d', '8k', '8d', '9d', '9d', '17k', ...

# %%
print(predict_result)
np.save("/content/drive/My Drive/기계학습 실습/prob.npy",predict_result)
# Out:
# [[3.8158994e-03 5.6418674e-03 6.1337375e-03 ... 7.7847287e-02
#   6.7103781e-02 4.7074198e-03]
#  [2.3481127e-02 2.0305295e-02 2.0243328e-02 ... 4.5356061e-02
#   4.8758093e-02 6.7212708e-02]
#  [2.5557628e-02 5.1133417e-02 7.4759021e-02 ... 1.9242188e-04
#   2.1667576e-04 4.9033833e-06]
#  ...
#  [7.2468533e-03 2.4725949e-02 2.9566064e-02 ... 1.7057458e-02
#   3.1336464e-02 1.8883873e-05]
#  [7.8889832e-02 1.8980888e-01 2.1987936e-01 ... 4.5925967e-04
#   6.1732024e-04 9.8199530e-07]
#  [3.5630316e-03 5.9804763e-03 1.4698682e-02 ... 1.0391606e-02
#   9.1353329e-03 4.9150252e-04]]

# %%
# !pip install pycryptodomex --no-binary :all:
import json
from base64 import b64encode
from Cryptodome.Cipher import AES
from Cryptodome.Util.Padding import pad

def read_txt(fileName):
    with open(fileName, 'rt') as f:
        list_data = [a.strip('\n\r') for a in f.readlines()]
    return list_data

def write_json(fileName, data):
    with open(fileName, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=4)

def load_key(key_path):
    with open(key_path, "rb") as f:
        key = f.read()
    return key

def encrypt_data(key_path, ans_list, encrypt_store_path='ans.json'):
    key = load_key(key_path)
    data = " ".join([str(i) for i in ans_list])
    encode_data = data.encode()
    cipher = AES.new(key, AES.MODE_CBC)
    ct_bytes = cipher.encrypt(pad(encode_data, AES.block_size))
    iv = b64encode(cipher.iv).decode('utf-8')
    ct = b64encode(ct_bytes).decode('utf-8')
    write_json(encrypt_store_path, {'iv':iv, 'ciphertext':ct})

if __name__=="__main__":
    # 1.이메일을 통해서 전달 받은 키 파일의 경로 입력
    key_path = "/content/drive/My Drive/기계학습 실습/team1.pem"
    # 2. 예측한 결과를 텍스트 파일로 저장했을 경우 리스트로 다시 불러오기
    # 본인이 원하는 방식으로 리스트 형태로 예측 값을 불러오기만 하면 됨(순서를 지킬것)
    #raw_ans_path = "ans.txt"
    #ans = read_txt(raw_ans_path)
    ans = pred_test_label_txt
    # 3. 암호화된 파일을 저장할 위치
    encrypt_ans_path = "/content/drive/My Drive/기계학습 실습/ans.json"
    # 4. 암호화!(pycrytodome 설치)
    encrypt_data(key_path, ans, encrypt_ans_path)
# Out:
# Collecting pycryptodomex
#   Downloading https://files.pythonhosted.org/packages/82/e2/a0f9f5452a59bafaa3420585f22b58a8566c4717a88c139af2276bb5695d/pycryptodomex-3.10.1.tar.gz (3.8MB)
#      |████████████████████████████████| 3.8MB 14.2MB/s
# Skipping wheel build for pycryptodomex, due to binaries being disabled for it.
# Installing collected packages: pycryptodomex
#     Running setup.py install for pycryptodomex ... done
# Successfully installed pycryptodomex-3.10.1
